# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import username, password, database

from sqlalchemy import create_engine, inspect

# %%
# Create Database Connection
engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/{database}")
conn = engine.connect()

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['employees', 'departments', 'dept_emp', 'dept_manager', 'salaries', 'titles']

# %%
#Create a dataframe shows salaries
salaries = pd.read_sql("SELECT * FROM salaries ORDER BY emp_no", conn)

salaries.head(10)
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228
# 5   10006   40000
# 6   10007   56724
# 7   10008   46671
# 8   10009   60929
# 9   10010   72488

# %%
#Create a histogram to visualize the most common salary ranges for employees.
fig=plt.figure(figsize=(10,5))
plt.hist(salaries["salary"])
plt.xlabel("Salary Range")
plt.ylabel("Number of Employees")
plt.ylim(0,160000)
plt.title("Salary Ranges for Employees", fontsize=10)
plt.grid()
plt.tight_layout()

#save the figure as a png file
plt.savefig('Output Images/Salary ranges for emplyees')

plt.show()

# %%
#create a dataframe to show titles and sort by title_id
titles = pd.read_sql("SELECT * FROM titles ORDER BY title_id", conn)
titles
# Out:
#   title_id               title
# 0    e0001  Assistant Engineer
# 1    e0002            Engineer
# 2    e0003     Senior Engineer
# 3    e0004    Technique Leader
# 4    m0001             Manager
# 5    s0001               Staff
# 6    s0002        Senior Staff

# %%
#create an amployees dataframe and sort by emp_no
employees = pd.read_sql("SELECT * FROM employees ORDER BY emp_no", conn)
employees.head(10)
# Out:
#    emp_no emp_title_id  birth_date first_name  last_name sex   hire_date
# 0   10001        e0003  1953-09-02     Georgi    Facello   M  1986-06-26
# 1   10002        s0001  1964-06-02    Bezalel     Simmel   F  1985-11-21
# 2   10003        e0003  1959-12-03      Parto    Bamford   M  1986-08-28
# 3   10004        e0003  1954-05-01  Chirstian    Koblick   M  1986-12-01
# 4   10005        s0001  1955-01-21    Kyoichi   Maliniak   M  1989-09-12
# 5   10006        e0003  1953-04-20     Anneke    Preusig   F  1989-06-02
# 6   10007        s0001  1957-05-23    Tzvetan  Zielinski   F  1989-02-10
# 7   10008        e0001  1958-02-19     Saniya   Kalloufi   M  1994-09-15
# 8   10009        e0003  1952-04-19     Sumant       Peac   F  1985-02-18
# 9   10010        e0002  1963-06-01  Duangkaew   Piveteau   F  1989-08-24

# %%
#Merge dataframs of Salaries and employees, join on emp_no
merge1 = pd.merge(salaries, employees, how='outer',on='emp_no')
merge1 = merge1.set_index('emp_no')
merge1 = merge1.rename(columns = {'emp_title_id':'title_id'})
merge1.head(10)
# Out:
#         salary title_id  birth_date first_name  last_name sex   hire_date
# emp_no
# 10001    60117    e0003  1953-09-02     Georgi    Facello   M  1986-06-26
# 10002    65828    s0001  1964-06-02    Bezalel     Simmel   F  1985-11-21
# 10003    40006    e0003  1959-12-03      Parto    Bamford   M  1986-08-28
# 10004    40054    e0003  1954-05-01  Chirstian    Koblick   M  1986-12-01
# 10005    78228    s0001  1955-01-21    Kyoichi   Maliniak   M  1989-09-12
# 10006    40000    e0003  1953-04-20     Anneke    Preusig   F  1989-06-02
# 10007    56724    s0001  1957-05-23    Tzvetan  Zielinski   F  1989-02-10
# 10008    46671    e0001  1958-02-19     Saniya   Kalloufi   M  1994-09-15
# 10009    60929    e0003  1952-04-19     Sumant       Peac   F  1985-02-18
# 10010    72488    e0002  1963-06-01  Duangkaew   Piveteau   F  1989-08-24

# %%
#Merge dataframs of titles and merge1, join on title_id
merge2 = pd.merge(merge1, titles, how='outer',on='title_id')
merge2 = merge2.set_index('title_id')
merge2.head(10)
# Out:
#           salary  birth_date first_name  last_name sex   hire_date  \
# title_id
# e0003      60117  1953-09-02     Georgi    Facello   M  1986-06-26
# e0003      40006  1959-12-03      Parto    Bamford   M  1986-08-28
# e0003      40054  1954-05-01  Chirstian    Koblick   M  1986-12-01
# e0003      40000  1953-04-20     Anneke    Preusig   F  1989-06-02
# e0003      60929  1952-04-19     Sumant       Peac   F  1985-02-18
# e0003      40000  1960-10-04   Patricio  Bridgland   M  1992-12-18
# e0003      55881  1954-06-19   Kazuhide       Peha   F  1987-04-03
# e0003      47585  1953-04-03   Yongqiao   Berztiss   M  1995-03-20
# e0003      40000  1962-07-10     Divier    Reistad   F  1989-07-07
# e0003      63163  1956-12-13      Otmar     Herbst   M  1985-11-20
#
#                     title
# title_id
# e0003     Senior Engineer
# e0003     Senior Engineer
# e0003     Senior Engineer
# e0003     Senior Engineer
# e0003     Senior Engineer
# e0003     Senior Engineer
# ...

# %%
avg_salary = pd.DataFrame(merge2.groupby('title').mean()['salary'].round(2))
avg_salary = avg_salary.sort_values(by='salary',ascending=True)
avg_salary
# Out:
#                       salary
# title
# Senior Engineer     48506.80
# Engineer            48535.34
# Assistant Engineer  48564.43
# Technique Leader    48582.90
# Manager             51531.04
# Staff               58465.38
# Senior Staff        58550.17

# %%
# Create a bar chart of average salary by title.
fig, ax = plt.subplots(figsize=(10,7))
fig = avg_salary.plot(kind="bar", legend=False, rot=75,ax=ax)

plt.title("Average Salary by Title", fontsize=10)
plt.xlabel("Title")
plt.ylabel("Average Salary")
plt.grid()
plt.tight_layout()

#save the figure as a png file
plt.savefig('Output Images/Average Salary by Title')

plt.show()

# %%
#Query my Employee ID = 499942
my_emp = pd.read_sql("SELECT * FROM employees WHERE emp_no = '499942'", conn)
my_emp
# Out:
#    emp_no emp_title_id  birth_date first_name last_name sex   hire_date
# 0  499942        e0004  1963-01-10      April  Foolsday   F  1997-02-10
